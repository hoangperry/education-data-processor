# %%
import glob
import random

import pandas as pd

# %%
list_file = glob.glob('./data-*.txt')
list_file
# Out:
# ['./data-2019.txt', './data-2020.txt', './data-2018.txt']

# %%
file_path = list_file[random.randint(0, len(list_file)-1)]
file_path = 'data-2019.txt'
data_file = pd.read_csv(file_path, sep='\t')
data_file
# Out:
#       World Rank                               Institution        Location   \
# 0               1                        Harvard University             USA
# 1               2     Massachusetts Institute of Technology             USA
# 2               3                       Stanford University             USA
# 3               4                   University of Cambridge  United Kingdom
# 4               5                      University of Oxford  United Kingdom
# ...           ...                                       ...             ...
# 1995         1996                  University of Klagenfurt         Austria
# 1996         1997         National University of Río Cuarto       Argentina
# 1997         1998                        Osmania University           India
# 1998         1999             Muğla Sıtkı Koçman University          Turkey
# 1999         2000  Government College University Faisalabad        Pakistan
#
# ...

# %%
file_path = list_file[random.randint(0, len(list_file)-1)]
file_path = 'data-2018.txt'
data_file = pd.read_csv(file_path, sep='\t')
data_file
# Out:
#      World Rank                            Institution        Location   \
# 0              1                     Harvard University             USA
# 1              2                    Stanford University             USA
# 2              3  Massachusetts Institute of Technology             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5                   University of Oxford  United Kingdom
# ..           ...                                    ...             ...
# 995          996                    Aga Khan University        Pakistan
# 996          997                 University of Calcutta           India
# 997          998                       Kōchi University           Japan
# 998          999               Soonchunhyang University     South Korea
# 999         1000              Capital Normal University           China
#
#      National Rank  Quality of Education  Alumni Employment   \
# ...

# %%
data_list = list()
for _, row in data_file[1:].iterrows():
    new_dict = dict()
    for i in zip(data_file.columns, row):
        new_dict[i[0].strip()] = i[1]
    data_list.append(new_dict)

# %%
def clean_university(university):
    for k, v in university.items():
        if isinstance(v, str):
            if v.isdigit():
                university[k] = int(v)
            elif re.match('>\s+\d+', v):
                university[k] = int(re.search(r'\d+', v).group())
            elif v.strip() == '-':
                university[k] = None
    return university

for i in data_list:
    clean_university(i)

# %%
data_list
# Out:
# [{'World Rank': 2,
#   'Institution': 'Massachusetts Institute of Technology',
#   'Location': 'USA',
#   'National Rank': 2,
#   'Quality of Education': 1,
#   'Alumni Employment': 10,
#   'Quality of Faculty': 2,
#   'Research Performance': 5,
#   'Score': 96.7},
#  {'World Rank': 3,
#   'Institution': 'Stanford University',
#   'Location': 'USA',
#   'National Rank': 3,
#   'Quality of Education': 9,
#   'Alumni Employment': 3,
#   'Quality of Faculty': 3,
#   'Research Performance': 2,
#   'Score': 95.2},
#  {'World Rank': 4,
#   'Institution': 'University of Cambridge',
#   'Location': 'United Kingdom',
#   'National Rank': 1,
#   'Quality of Education': 4,
#   'Alumni Employment': 19,
#   'Quality of Faculty': 5,
#   'Research Performance': 11,
#   'Score': 94.1},
#  {'World Rank': 5,
#   'Institution': 'University of Oxford',
#   'Location': 'United Kingdom',
#   'National Rank': 2,
#   'Quality of Education': 10,
#   'Alumni Employment': 24,
#   'Quality of Faculty': 10,
# ...

# %%
from pymongo import MongoClient

def create_mongo_url_connection(username, password, host, port):
    return f'mongodb://{username}:{password}@{host}:{port}/edu_db/'

# %%
from pymongo import MongoClient

client = MongoClient('mongodb://hoangntruong:NYTPnHoang@ai.hoang.tech:27018/edu_db/')
db_connection = client['edudb']
db_connection.educl.update({'123123': 1})
client.close()
# Out:
# <ipython-input-77-7ad86d0ad584>:5: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   db_connection.educl.insert({'123123': 1})

# %%
db_connection.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-0cfbf842c2f5> in <module>
# ----> 1 db_connection.close()
#
# ~/.local/lib/python3.8/site-packages/pymongo/collection.py in __call__(self, *args, **kwargs)
#    3484         """
#    3485         if "." not in self.__name:
# -> 3486             raise TypeError("'Collection' object is not callable. If you "
#    3487                             "meant to call the '%s' method on a 'Database' "
#    3488                             "object it is failing because no such method "
#
# TypeError: 'Collection' object is not callable. If you meant to call the 'close' method on a 'Database' object it is failing because no such method exists.
